# %% [markdown]
# # **API Testing Notes**

# %% [markdown]
# ## **Install Python:**
# - `brew install python3`
# - `which python3`
# - `which -a python3`
#
# ## **Python Virtual Environments**
# - Create virtual env
# - `python3 -m venv venv`
# - On Mac Use : `source venv/bin/activate`
# - On Windows use : `venv\Scripts\activate`
# - To deactivate :`deactivate`
#
# Then Install libraries/ Packages
# - pip install requests
# - pip install pytest
# - pip install pymysql
#
# - `pip freeze` give us list of installed packages

# %% [markdown]
# ## **WordPress Needs To Run**
# **WordPress**
# - Downloaded set of files
#
# **Database**
# - MySQL
#
# **Web Server**
# - Apache
# - NginX
#
# **PHP**
#
#
# ## **Options for WordPress**
# - mamp.info
# - docker.com
# - localwp.com
# - Manual Install
#
#
# ## **Run WordPress with MAMP**
# - MAMP download
# - Start MAMP, Check Genaral, note Ports and Server(MYSQL)
# - DownLoad WordPress (WordPress.org), unzip it , copy all content of it, Go to MAMP-> server-> open in finder -> create a folder(ex: coolsite) -> and paste all content in it
# - go to browser localhost:8888 -> This is MAMP
# - go to browser localhost:8888/coolsite -> This is your website for setup
# - Need Database , so create it (Use mysql workbench)
#
#
# ## **Installing Local**

# %%
from IPython.display import Image, display
display(Image(filename='test.png'))

# %% [markdown]
# - Create a setup.py in root folder
# - activate virtual environment venv `python3 setup.py install`
# - run setup.py 'python3 setup.py install'

# %% [markdown]
# ## **What is difference between package and folder in python3**
#
# In Python, **packages** and **folders** serve different purposes, even though they are often related in the file system:
#
# ### 1. **Folder:**
#    - A folder is a directory in your file system that is used to organize files and subdirectories. It is a general-purpose storage space and does not have any specific functionality in Python by itself.
#    - In Python, a folder can contain Python files, but unless it is treated as a package (see below), it is just a regular directory and cannot be directly imported.
#
# ### 2. **Package:**
#    - A package is a special kind of folder in Python that allows you to organize related Python modules (files containing Python code) and make them importable.
#    - A folder becomes a Python package when it contains an `__init__.py` file. This file can be empty, or it can include initialization code for the package.
#    - Packages help in structuring large codebases by organizing modules into a hierarchical structure. You can import modules from packages using the dot notation, e.g., `from package.module import function`.
#
# ### Key Differences:
#    - **Purpose:**
#      - A folder is used for file organization, while a package is designed to structure and manage Python code modules.
#    - **`__init__.py`:**
#      - A package requires an `__init__.py` file to be recognized as a package by Python. A folder does not.
#    - **Importability:**
#      - You can import a package and its modules using Python’s import system (`import package.module`). A folder without `__init__.py` is not importable.
#
# ### Example:
# ```bash
# project/
# │
# ├── my_folder/               # Just a folder for organizing files
# │   ├── file.txt
# │   └── image.jpg
# │
# ├── my_package/              # A Python package
# │   ├── __init__.py          # This makes 'my_package' a package
# │   ├── module1.py
# │   └── module2.py
# ```
#
# - You can import `module1` from `my_package` in your Python code:
#   ```python
#   from my_package import module1
#   ```
#
# ---

# %% [markdown]
# ## **Explain install vs devlop wrt python**
#
# In Python, the terms **"install"** and **"develop"** refer to different approaches when working with Python packages. They serve distinct purposes in the context of Python package management, especially when dealing with custom or third-party libraries.
#
# ### 1. **Install Mode:**
#    - **Purpose:** When you install a Python package, the package is copied from its source location (like PyPI or a local directory) into your Python environment’s `site-packages` directory.
#    - **Command:**
#      - For installing a package from PyPI (or other sources):
#        ```bash
#        pip install package_name
#        ```
#      - To install from a local directory:
#        ```bash
#        pip install .
#        ```
#    - **How it Works:**
#      - The package gets installed into the Python environment, making it available to be imported and used anywhere in that environment.
#      - Once installed, the package code is **static**. If you change the source files of the installed package, you must reinstall the package to reflect the changes.
#
#    - **Use Case:**
#      - Use `install` when you want to use a package in its final form without modifying its source code, or when using a package from an external source like PyPI.
#
#    - **Typical Scenario:**
#      - After installing a package, you can use it immediately in your projects:
#        ```python
#        import my_installed_package
#        ```
#
# ### 2. **Develop Mode (Editable Mode):**
#    - **Purpose:** In "develop" mode (also known as **editable install**), the package is linked to its source directory instead of being copied into the Python environment. This allows you to modify the package's source code, and the changes will immediately reflect without needing to reinstall the package.
#    - **Command:**
#      - To install in develop mode from a local directory:
#        ```bash
#        pip install -e .
#        ```
#      - The `-e` or `--editable` flag tells `pip` to install the package in "editable" mode.
#    - **How it Works:**
#      - The package is not fully installed into `site-packages`. Instead, Python creates a symbolic link (or pointer) to the original source directory.
#      - Any changes made to the source code are automatically available in your environment without needing to reinstall or run the installation process again.
#
#    - **Use Case:**
#      - Use `develop` mode when you're actively developing a Python package or library. It’s particularly useful when you're iterating on the code and need changes to be reflected immediately for testing or debugging purposes.
#
#    - **Typical Scenario:**
#      - If you're working on a custom package or contributing to an open-source project, you can use develop mode to easily test your changes:
#        ```bash
#        cd my_project
#        pip install -e .
#        ```
#      - This makes `my_project` available as an editable package that you can import, and any code changes you make will be immediately reflected.
#
# ### Key Differences:
# | Feature           | Install Mode                       | Develop Mode (Editable Install)            |
# |-------------------|------------------------------------|--------------------------------------------|
# | **Installation**   | Copies the package into `site-packages`. | Links to the source directory using a symbolic link. |
# | **Code Changes**   | Changes in the source code require reinstallation. | Changes in the source code are immediately reflected. |
# | **Use Case**       | When using the package without making modifications. | When developing or modifying the package. |
# | **Typical Command**| `pip install package_name` or `pip install .` | `pip install -e .` |
#
# ### Summary:
# - **Install Mode** is for when you’re using a package as-is, while **Develop Mode** (editable mode) is for when you need to actively work on and modify the package's source code.
#
# ---
